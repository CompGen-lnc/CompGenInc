# %%
import gensim
from Bio import SeqIO

# %%
def read_fa(path):
    res={}
    rescords = list(SeqIO.parse(path,format="fasta"))
    for x in rescords:
        id = str(x.id)
        mayus=str(x.seq).upper()
        seq = str(mayus).replace("U","T")
        res[id]=seq
    return res

# %%
def train_doc2vec_model(seq_list,model_name):
    tokens = []
    for i, seq in enumerate(seq_list):
        items = []
        k = 0
        while k + 3 < len(seq):
            item = seq[k:k + 3]
            items.append(item)
            k = k + 1
        doc2vec_data = gensim.models.doc2vec.TaggedDocument(items, [i])
        tokens.append(doc2vec_data)
    print("-----begin train-----")
    model = gensim.models.doc2vec.Doc2Vec(vector_size=256, min_count=3, epochs=100, workers=12)
    model.build_vocab(tokens)
    model.train(tokens, total_examples=model.corpus_count, epochs=model.epochs)
    model.save("/Users/andrescubillovillalobos/Documents/CompGen_Inc/CNN_lnc_mIR/Embedding/Modelos/"+model_name+".model")

# %%
mirna_dict = read_fa("/Users/andrescubillovillalobos/Documents/CompGen_Inc/RedNeuronal1/data/fasta/fasta_seq/miRNA.fa")
mirna_list = list(mirna_dict.values())
train_doc2vec_model(mirna_dict,"mirna_precursor_doc2vec")
# Out:
# -----begin train-----

# %%
mirna_dict = read_fa("/Users/andrescubillovillalobos/Documents/CompGen_Inc/RedNeuronal1/data/fasta/fasta_seq/miRNA_Especifico.fa")
mirna_list = list(mirna_dict.values())
train_doc2vec_model(mirna_dict,"mirna_especifico_doc2vec")
# Out:
# -----begin train-----
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
lncrna_dict = read_fa("/Users/andrescubillovillalobos/Documents/CompGen_Inc/RedNeuronal1/data/fasta/fasta_seq/lncRNA.fa")
lncrna_list = list(lncrna_dict.values())
train_doc2vec_model(lncrna_list,"lncrna_doc2vec")
# Out:
# -----begin train-----
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# ...
